# %% [markdown]
# # Fall Semester 2024
#
# **Course:** Python Programming (CS 2023) <br>
# **Section:** 002 <br>
# **Location:** REC CENTER 3210 <br>
# **Days/Times:** TuTh 3:30-4:50 <br>
# **Office Hours:** TuTh immediately following class.<br>
# **Instruction Mode:** This course is a face-to-face, in-person course. This means that class will be conducted entirely via in-person class meetings that take place at the location and times noted. <br>
# **Textbook:** The primary textbook for this course is [Scientific Computing with Python](https://learning.oreilly.com/library/view/scientific-computing-with/9781838822323/). This book is available online through UC's institutional agreement with O'Reilly Media. See the following [FAQ](/faq/oreilly/oreilly_access.md) for access instructions. Supplemental materials will be provided as needed throughout the semester.
#
# ```{note}
# As in all university courses, attendance and participation are important measures of student success. In this course, attendance is not recorded. Your attendance and participation are still expected.
# ```

# %%
import pandas as pd
from IPython.core.display import HTML

# %%
schedule = pd.read_csv('20CS2023-FS24.tsv', sep='\t')

schedule['Date']= pd.to_datetime(schedule['Date'])
schedule.sort_values(by=['Date'], inplace=True, ascending=True)
schedule['Date'] = schedule['Date'].dt.strftime('%b-%d')

# Define column widths (in pixels) by index
schedule['Topics'] = schedule['Topics'].str.replace(';', '<br>')
schedule['Item(s) Due'] = schedule['Item(s) Due'].str.replace(';', '<br>')
schedule['Reading Material'] = schedule['Reading Material'].str.replace(';', '<br>')

schedule_html = schedule.to_html(index=False, escape=False)
#schedule_html = schedule_html.replace('<table border="1" class="dataframe">','<table class="table table-bordered">')

wrapped_html = f'<div class="mystyle">{schedule_html}</div>'

# %% [markdown]
# ## Schedule

# %%
HTML(wrapped_html)
# Out:
# <div class="mystyle"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Date</th>
#       <th>Topics</th>
#       <th>Reading Material</th>
#       <th>Item(s) Due</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Aug-27</td>
#       <td>Course overview, Python environment, GitHub / GitHub Classroom, Jupyter Notebook</td>
#       <td>Ch 1.1</td>
#       <td>Knowledge Check L1</td>
#     </tr>
#     <tr>
#       <td>Aug-29</td>
#       <td>Variables and Basic Types</td>
#       <td>Ch 1.2-1.8<br> Ch 2</td>
#       <td>Knowledge Check L2</td>
#     </tr>
#     <tr>
#       <td>Sep-03</td>
#       <td>Data Structures pt.1</td>
#       <td>Ch 3</td>
#       <td>Knowledge Check L3</td>
#     </tr>
#     <tr>
#       <td>Sep-05</td>
#       <td>Data Structures pt.2</td>
#       <td>Ch 3</td>
#       <td>Knowledge Check L4</td>
#     </tr>
#     <tr>
#       <td>Sep-10</td>
#       <td>Functions, Program Flow, Iterating</td>
#       <td>Ch 7<br> Ch 9</td>
#       <td>Knowledge Check L5<br> Programming Assignment 1</td>
#     </tr>
#     <tr>
#       <td>Sep-12</td>
#       <td>Classes pt.1</td>
#       <td>Ch 8</td>
#       <td>Knowledge Check L6</td>
#     </tr>
#     <tr>
#       <td>Sep-17</td>
#       <td>Classes pt.2</td>
#       <td>Ch 8</td>
#       <td>Knowledge Check L7</td>
#     </tr>
#     <tr>
#       <td>Sep-19</td>
#       <td>Errors, Exception Handling and Debugging</td>
#       <td>Ch 12</td>
#       <td>Knowledge Check L8</td>
#     </tr>
#     <tr>
#       <td>Sep-24</td>
#       <td>Namespaces, Scopes, and Modules</td>
#       <td>Ch 13</td>
#       <td>Knowledge Check L9</td>
#     </tr>
#     <tr>
#       <td>Sep-26</td>
#       <td>Testing, Profiling, Optimization pt.1</td>
#       <td>Ch 15</td>
#       <td>Knowledge Check L10</td>
#     </tr>
#     <tr>
#       <td>Oct-01</td>
#       <td>Testing, Profiling, Optimization pt.2</td>
#       <td>Ch 15</td>
#       <td>Knowledge Check L11<br> Programming Assignment 2</td>
#     </tr>
#     <tr>
#       <td>Oct-03</td>
#       <td>Scripts, Packages, and Libraries</td>
#       <td>TBD</td>
#       <td>Knowledge Check L12</td>
#     </tr>
#     <tr>
#       <td>Oct-08</td>
#       <td>Midterm Review</td>
#       <td>---</td>
#       <td>---</td>
#     </tr>
#     <tr>
#       <td>Oct-10</td>
#       <td>Midterm Exam</td>
#       <td>---</td>
#       <td>Midterm Exam</td>
#     </tr>
#     <tr>
#       <td>Oct-15</td>
#       <td>Stacks and Queues</td>
#       <td>TBD</td>
#       <td>Knowledge Check L13</td>
#     </tr>
#     <tr>
#       <td>Oct-17</td>
#       <td>Arrays and Linear Algebra pt.1</td>
#       <td>Ch 4</td>
#       <td>Knowledge Check L14</td>
#     </tr>
#     <tr>
#       <td>Oct-22</td>
#       <td>Arrays and Linear Algebra pt.2</td>
#       <td>Ch 5</td>
#       <td>Knowledge Check L15<br> Programming Assignment 3</td>
#     </tr>
#     <tr>
#       <td>Oct-24</td>
#       <td>Visualization</td>
#       <td>Ch 6</td>
#       <td>Knowledge Check L16</td>
#     </tr>
#     <tr>
#       <td>Oct-29</td>
#       <td>Series and Dataframes</td>
#       <td>Ch 10</td>
#       <td>Knowledge Check L17</td>
#     </tr>
#     <tr>
#       <td>Oct-31</td>
#       <td>Input and Output, Interacting with the Operating System</td>
#       <td>Ch 14<br> Ch 17</td>
#       <td>Knowledge Check L18</td>
#     </tr>
#     <tr>
#       <td>Nov-05</td>
#       <td>No Class<br> Reading Day</td>
#       <td>---</td>
#       <td>---</td>
#     </tr>
#     <tr>
#       <td>Nov-07</td>
#       <td>Graphical User Interfaces, The Internet</td>
#       <td>Ch 11</td>
#       <td>Knowledge Check L19</td>
#     </tr>
#     <tr>
#       <td>Nov-12</td>
#       <td>Symbolic Computations, Parallel Computing</td>
#       <td>Ch 16<br> Ch 18</td>
#       <td>Knowledge Check L20<br> Programming Assignment 4</td>
#     </tr>
#     <tr>
#       <td>Nov-14</td>
#       <td>Applications in Scientific Computing</td>
#       <td>Ch 19</td>
#       <td>Knowledge Check L21</td>
#     </tr>
#     <tr>
#       <td>Nov-19</td>
#       <td>Applications in Machine Learning pt.1</td>
#       <td>TBD</td>
#       <td>Knowledge Check L22</td>
#     </tr>
#     <tr>
#       <td>Nov-21</td>
#       <td>Applications in Machine Learning pt.2</td>
#       <td>TBD</td>
#       <td>Knowledge Check L23</td>
#     </tr>
#     <tr>
#       <td>Nov-26</td>
#       <td>Applications in Deep Learning pt.1</td>
#       <td>TBD</td>
#       <td>Knowledge Check L24</td>
#     </tr>
#     <tr>
#       <td>Nov-28</td>
#       <td>No Class<br> Thanksgiving Weekend</td>
#       <td>---</td>
#       <td>---</td>
#     </tr>
#     <tr>
#       <td>Dec-03</td>
#       <td>Applications in Deep Learning pt.2</td>
#       <td>TBD</td>
#       <td>Knowledge Check 25<br> Programming Assignment 5</td>
#     </tr>
#     <tr>
#       <td>Dec-05</td>
#       <td>Final Review</td>
#       <td>---</td>
#       <td>---</td>
#     </tr>
#     <tr>
#       <td>Dec-12</td>
#       <td>Final Exam<br> 12:30 pm–2:30 pm</td>
#       <td>---</td>
#       <td>Final Exam</td>
#     </tr>
#   </tbody>
# </table></div>
